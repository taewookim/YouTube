# %% [markdown]
# # Ep 6 - Balance Sheet Analysis
# ## Value Investing Stock Analysis with Python
#
# ### Topics Covered
#
# - Basic Balance Sheet Analysis
# - Looking for Trends
# - Introduction to ratios
# - Plotly Graphing
#
#
# Couple of notes:
#
#
# ## Book that I learned from
# ![title](images/1983654.jpg)
#
#
# ## Note from SimFin CEO
#
# ![title](images/simfin_error.jpg)
#
#
#     You are right with the interaction of the downloaded files and pandas - I changed the format from .xls to .xlsx now, I think it works now. The only thing I had to install additionally was XLRD (conda install xlrd) in order for Pandas to load the file.
#
#
# If you haven't done so, run
#
#     !conda install xlrd
#
#
# ## Jupyter notebook markdown cheatsheet
#
# https://medium.com/ibm-data-science-experience/markdown-for-jupyter-notebooks-cheatsheet-386c05aeebed

# %%
from tk_library import excel_to_df

# %%
_, nvda_PL, nvda_BS, nvda_CF = excel_to_df("NVDA_Q.xls")

# %%
nvda_BS
# Out:
# in million USD  Assets  Cash and cash equivalents  Marketable securities  \
# 20
# Q2 '15               0                        435                   4070
# Q3 '15               0                        471                   4257
# Q4 '15               0                        596                   4441
# Q1 '16               0                        547                   4207
# Q2 '16               0                        426                   4453
# Q3 '16               0                       1940                   4731
# Q4 '16               0                       1766                   5032
# Q1 '17               0                       1989                   4217
# Q2 '17               0                       1988                   3889
# Q3 '17               0                       2802                   3518
# Q4 '17               0                       4002                   3106
# Q1 '18               0                        765                   6535
#
# in million USD  Accounts receivable, net  Inventories  \
# 20
# Q2 '15                               514          441
# Q3 '15                               536          425
# Q4 '15                               505          418
# Q1 '16                               523          394
# Q2 '16                               644          521
# Q3 '16                               833          679
# Q4 '16                               826          794
# Q1 '17                               976          821
# Q2 '17                              1213          855
# Q3 '17                              1167          857
# Q4 '17                              1265          796
# Q1 '18                              1220          797
#
# in million USD  Prepaid expenses and other current assets  \
# 20
# Q2 '15                                                 89
# Q3 '15                                                 93
# Q4 '15                                                 93
# Q1 '16                                                119
# Q2 '16                                                112
# Q3 '16                                                124
# Q4 '16                                                118
# Q1 '17                                                113
# Q2 '17                                                125
# Q3 '17                                                135
# Q4 '17                                                 86
# Q1 '18                                                131
#
# in million USD  Deferred income taxes  Total current assets  \
# 20
# Q2 '15                             59                  5608
# Q3 '15                             52                  5834
# Q4 '15                              0                  6053
# Q1 '16                              0                  5790
# Q2 '16                              0                  6156
# Q3 '16                              0                  8307
# Q4 '16                              0                  8536
# Q1 '17                              0                  8116
# Q2 '17                              0                  8070
# Q3 '17                              0                  8479
# Q4 '17                              0                  9255
# Q1 '18                              0                  9448
#
# in million USD  Property and equipment, net  Goodwill  \
# 20
# Q2 '15                                  497       618
# Q3 '15                                  477       618
# Q4 '15                                  466       618
# Q1 '16                                  479       618
# Q2 '16                                  485       618
# Q3 '16                                  503       618
# Q4 '16                                  521       618
# Q1 '17                                  539       618
# Q2 '17                                  578       618
# Q3 '17                                  600       618
# Q4 '17                                  997       618
# Q1 '18                                 1066       618
#
# in million USD                                         ...                                          \
# 20                                                     ...
# Q2 '15                                                 ...
# Q3 '15                                                 ...
# Q4 '15                                                 ...
# Q1 '16                                                 ...
# Q2 '16                                                 ...
# Q3 '16                                                 ...
# Q4 '16                                                 ...
# Q1 '17                                                 ...
# Q2 '17                                                 ...
# Q3 '17                                                 ...
# Q4 '17                                                 ...
# Q1 '18                                                 ...
#
# in million USD  Commitments and Contingencies - see Note 12  \
# 20
# Q2 '15                                                    0
# Q3 '15                                                    0
# Q4 '15                                                    0
# Q1 '16                                                    0
# Q2 '16                                                    0
# Q3 '16                                                    0
# Q4 '16                                                    0
# Q1 '17                                                    0
# Q2 '17                                                    0
# Q3 '17                                                    0
# Q4 '17                                                    0
# Q1 '18                                                    0
#
# in million USD  Convertible debt conversion obligation  Preferred stock  \
# 20
# Q2 '15                                               0                0
# Q3 '15                                               0                0
# Q4 '15                                              87                0
# Q1 '16                                              79                0
# Q2 '16                                              72                0
# Q3 '16                                              45                0
# Q4 '16                                              31                0
# Q1 '17                                               7                0
# Q2 '17                                               2                0
# Q3 '17                                               1                0
# Q4 '17                                               0                0
# Q1 '18                                               0                0
#
# in million USD  Common stock  Additional paid-in capital  \
# 20
# Q2 '15                     1                        3938
# Q3 '15                     1                        4170
# Q4 '15                     1                        4170
# Q1 '16                     1                        4218
# Q2 '16                     1                        4408
# Q3 '16                     1                        4581
# Q4 '16                     1                        4708
# Q1 '17                     1                        4936
# Q2 '17                     1                        5048
# Q3 '17                     1                        5219
# Q4 '17                     1                        5351
# Q1 '18                     1                        5546
#
# in million USD  Treasury stock, at cost  Accumulated other comprehensive loss  \
# 20
# Q2 '15                            -3765                                     1
# Q3 '15                            -3912                                     2
# Q4 '15                            -4048                                    -4
# Q1 '16                            -4508                                     1
# Q2 '16                            -4608                                     4
# Q3 '16                            -4783                                    -4
# Q4 '16                            -5039                                   -16
# Q1 '17                            -5297                                   -14
# Q2 '17                            -6070                                   -12
# Q3 '17                            -6614                                   -14
# Q4 '17                            -6650                                   -18
# Q1 '18                            -7755                                   -23
#
# in million USD  Retained earnings  Total shareholders' equity  \
# 20
# Q2 '15                       4010                        4185
# Q3 '15                       4204                        4465
# Q4 '15                       4350                        4469
# Q1 '16                       4484                        4196
# Q2 '16                       4675                        4480
# Q3 '16                       5529                        5324
# Q4 '16                       6108                        5762
# Q1 '17                       6506                        6132
# Q2 '17                       7006                        5973
# Q3 '17                       7760                        6352
# Q4 '17                       8787                        7471
# Q1 '18                       9948                        7717
#
# in million USD  Total liabilities, convertible debt conversion obligation and shareholders' equity
# 20
# Q2 '15                                                       6979
# Q3 '15                                                       7174
# Q4 '15                                                       7370
# Q1 '16                                                       7108
# Q2 '16                                                       7461
# Q3 '16                                                       9612
# Q4 '16                                                       9841
# Q1 '17                                                       9410
# Q2 '17                                                       9402
# Q3 '17                                                       9830
# Q4 '17                                                      11241
# Q1 '18                                                      11460
#
# [12 rows x 32 columns]

# %%
del(nvda_BS["Assets"])

# %%
nvda_BS
# Out:
# in million USD  Cash and cash equivalents  Marketable securities  \
# 20
# Q2 '15                                435                   4070
# Q3 '15                                471                   4257
# Q4 '15                                596                   4441
# Q1 '16                                547                   4207
# Q2 '16                                426                   4453
# Q3 '16                               1940                   4731
# Q4 '16                               1766                   5032
# Q1 '17                               1989                   4217
# Q2 '17                               1988                   3889
# Q3 '17                               2802                   3518
# Q4 '17                               4002                   3106
# Q1 '18                                765                   6535
#
# in million USD  Accounts receivable, net  Inventories  \
# 20
# Q2 '15                               514          441
# Q3 '15                               536          425
# Q4 '15                               505          418
# Q1 '16                               523          394
# Q2 '16                               644          521
# Q3 '16                               833          679
# Q4 '16                               826          794
# Q1 '17                               976          821
# Q2 '17                              1213          855
# Q3 '17                              1167          857
# Q4 '17                              1265          796
# Q1 '18                              1220          797
#
# in million USD  Prepaid expenses and other current assets  \
# 20
# Q2 '15                                                 89
# Q3 '15                                                 93
# Q4 '15                                                 93
# Q1 '16                                                119
# Q2 '16                                                112
# Q3 '16                                                124
# Q4 '16                                                118
# Q1 '17                                                113
# Q2 '17                                                125
# Q3 '17                                                135
# Q4 '17                                                 86
# Q1 '18                                                131
#
# in million USD  Deferred income taxes  Total current assets  \
# 20
# Q2 '15                             59                  5608
# Q3 '15                             52                  5834
# Q4 '15                              0                  6053
# Q1 '16                              0                  5790
# Q2 '16                              0                  6156
# Q3 '16                              0                  8307
# Q4 '16                              0                  8536
# Q1 '17                              0                  8116
# Q2 '17                              0                  8070
# Q3 '17                              0                  8479
# Q4 '17                              0                  9255
# Q1 '18                              0                  9448
#
# in million USD  Property and equipment, net  Goodwill  Intangible assets, net  \
# 20
# Q2 '15                                  497       618                     190
# Q3 '15                                  477       618                     172
# Q4 '15                                  466       618                     166
# Q1 '16                                  479       618                     155
# Q2 '16                                  485       618                     138
# Q3 '16                                  503       618                     120
# Q4 '16                                  521       618                     104
# Q1 '17                                  539       618                      90
# Q2 '17                                  578       618                      76
# Q3 '17                                  600       618                      63
# Q4 '17                                  997       618                      52
# Q1 '18                                 1066       618                      55
#
# in million USD                                         ...                                          \
# 20                                                     ...
# Q2 '15                                                 ...
# Q3 '15                                                 ...
# Q4 '15                                                 ...
# Q1 '16                                                 ...
# Q2 '16                                                 ...
# Q3 '16                                                 ...
# Q4 '16                                                 ...
# Q1 '17                                                 ...
# Q2 '17                                                 ...
# Q3 '17                                                 ...
# Q4 '17                                                 ...
# Q1 '18                                                 ...
#
# in million USD  Commitments and Contingencies - see Note 12  \
# 20
# Q2 '15                                                    0
# Q3 '15                                                    0
# Q4 '15                                                    0
# Q1 '16                                                    0
# Q2 '16                                                    0
# Q3 '16                                                    0
# Q4 '16                                                    0
# Q1 '17                                                    0
# Q2 '17                                                    0
# Q3 '17                                                    0
# Q4 '17                                                    0
# Q1 '18                                                    0
#
# in million USD  Convertible debt conversion obligation  Preferred stock  \
# 20
# Q2 '15                                               0                0
# Q3 '15                                               0                0
# Q4 '15                                              87                0
# Q1 '16                                              79                0
# Q2 '16                                              72                0
# Q3 '16                                              45                0
# Q4 '16                                              31                0
# Q1 '17                                               7                0
# Q2 '17                                               2                0
# Q3 '17                                               1                0
# Q4 '17                                               0                0
# Q1 '18                                               0                0
#
# in million USD  Common stock  Additional paid-in capital  \
# 20
# Q2 '15                     1                        3938
# Q3 '15                     1                        4170
# Q4 '15                     1                        4170
# Q1 '16                     1                        4218
# Q2 '16                     1                        4408
# Q3 '16                     1                        4581
# Q4 '16                     1                        4708
# Q1 '17                     1                        4936
# Q2 '17                     1                        5048
# Q3 '17                     1                        5219
# Q4 '17                     1                        5351
# Q1 '18                     1                        5546
#
# in million USD  Treasury stock, at cost  Accumulated other comprehensive loss  \
# 20
# Q2 '15                            -3765                                     1
# Q3 '15                            -3912                                     2
# Q4 '15                            -4048                                    -4
# Q1 '16                            -4508                                     1
# Q2 '16                            -4608                                     4
# Q3 '16                            -4783                                    -4
# Q4 '16                            -5039                                   -16
# Q1 '17                            -5297                                   -14
# Q2 '17                            -6070                                   -12
# Q3 '17                            -6614                                   -14
# Q4 '17                            -6650                                   -18
# Q1 '18                            -7755                                   -23
#
# in million USD  Retained earnings  Total shareholders' equity  \
# 20
# Q2 '15                       4010                        4185
# Q3 '15                       4204                        4465
# Q4 '15                       4350                        4469
# Q1 '16                       4484                        4196
# Q2 '16                       4675                        4480
# Q3 '16                       5529                        5324
# Q4 '16                       6108                        5762
# Q1 '17                       6506                        6132
# Q2 '17                       7006                        5973
# Q3 '17                       7760                        6352
# Q4 '17                       8787                        7471
# Q1 '18                       9948                        7717
#
# in million USD  Total liabilities, convertible debt conversion obligation and shareholders' equity
# 20
# Q2 '15                                                       6979
# Q3 '15                                                       7174
# Q4 '15                                                       7370
# Q1 '16                                                       7108
# Q2 '16                                                       7461
# Q3 '16                                                       9612
# Q4 '16                                                       9841
# Q1 '17                                                       9410
# Q2 '17                                                       9402
# Q3 '17                                                       9830
# Q4 '17                                                      11241
# Q1 '18                                                      11460
#
# [12 rows x 31 columns]

# %%
nvda_BS["_Total Current Assets"] = nvda_BS["Cash and cash equivalents"] + nvda_BS["Marketable securities"] + nvda_BS["Accounts receivable, net"] + nvda_BS["Inventories"] + nvda_BS["Prepaid expenses and other current assets"]+ nvda_BS["Deferred income taxes"]

# %%
nvda_BS[["_Total Current Assets", "Total current assets"]]
# Out:
# in million USD  _Total Current Assets  Total current assets
# 20
# Q2 '15                           5608                  5608
# Q3 '15                           5834                  5834
# Q4 '15                           6053                  6053
# Q1 '16                           5790                  5790
# Q2 '16                           6156                  6156
# Q3 '16                           8307                  8307
# Q4 '16                           8536                  8536
# Q1 '17                           8116                  8116
# Q2 '17                           8070                  8070
# Q3 '17                           8479                  8479
# Q4 '17                           9255                  9255
# Q1 '18                           9448                  9448

# %%
nvda_BS["_Not_current_assets"] = nvda_BS["Property and equipment, net"] + nvda_BS["Goodwill"] + nvda_BS["Intangible assets, net"] + nvda_BS["Other assets"]

# %%
nvda_BS["_Total Assets"] = nvda_BS["_Not_current_assets"] + nvda_BS["_Total Current Assets"]

# %%
nvda_BS[["_Total Assets", "Total assets"]]
# Out:
# in million USD  _Total Assets  Total assets
# 20
# Q2 '15                   6979          6979
# Q3 '15                   7174          7174
# Q4 '15                   7370          7370
# Q1 '16                   7108          7108
# Q2 '16                   7461          7461
# Q3 '16                   9612          9612
# Q4 '16                   9841          9841
# Q1 '17                   9410          9410
# Q2 '17                   9402          9402
# Q3 '17                   9830          9830
# Q4 '17                  11241         11241
# Q1 '18                  11460         11460

# %%
nvda_BS["_Total Liabilities"] = nvda_BS["Accounts payable"] + nvda_BS["Accrued and other current liabilities"] +  nvda_BS["Convertible debt, short-term"] + nvda_BS["Long-term debt"] +  nvda_BS["Other long-term liabilities"] +  nvda_BS["Capital lease obligations, long term"]

# %%
nvda_BS[["_Total Liabilities", "Total liabilities"]]
# Out:
# in million USD  _Total Liabilities  Total liabilities
# 20
# Q2 '15                        2794                  0
# Q3 '15                        2709                  0
# Q4 '15                        2814               2814
# Q1 '16                        2833               2833
# Q2 '16                        2909               2909
# Q3 '16                        4243               4243
# Q4 '16                        4048               4048
# Q1 '17                        3271               3271
# Q2 '17                        3427               3427
# Q3 '17                        3477               3477
# Q4 '17                        3770               3770
# Q1 '18                        3743               3743

# %% [markdown]
# # Balance Sheet Analysis
#
# ## ALE
#
# Not this kind
# ![title](images/ale.jpg)
#
# This kind
# ![title](images/ale-finance.png)

# %%
# %matplotlib inline
nvda_BS[ ["Total assets", "Total liabilities", "Total shareholders' equity"] ].plot()

# %%
good_stuff = '''
Cash and cash equivalents
Marketable securities
Accounts receivable, net
Inventories
Prepaid expenses and other current assets
Deferred income taxes
'''

# %%
asset_columns = [ x for x in good_stuff.strip().split("\n")]

# %%
asset_columns
# Out:
# ['Cash and cash equivalents',
#  'Marketable securities',
#  'Accounts receivable, net',
#  'Inventories',
#  'Prepaid expenses and other current assets',
#  'Deferred income taxes']

# %%
nvda_BS[ asset_columns ].plot()

# %%
import plotly

# %%
# plotly.tools.set_credentials_file(username="XYZ", api_key="API_KEY")

# %%
import plotly.plotly as py
import plotly.graph_objs as go

# %%
assets = go.Bar(
    x=nvda_BS.index,
    y=nvda_BS["Total assets"],
    name="Total assets"
)
liabilities = go.Bar(
    x=nvda_BS.index,
    y=nvda_BS["Total liabilities"],
    name="Total liabilities"
)

shareholder_equity = go.Scatter(
    x=nvda_BS.index,
    y=nvda_BS["Total shareholders' equity"],
    name="Total shareholders' equity"
)

data = [assets, liabilities, shareholder_equity]

layout = go.Layout(barmode="stack")

fig_bs = go.Figure(data=data, layout=layout)
py.iplot(fig_bs, filename='Total Assets and Liabilities')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~taewoo/11.embed" height="525px" width="100%"></iframe>

# %%
asset_data = []
columns='''
Cash and cash equivalents
Marketable securities
Accounts receivable, net
Inventories
Prepaid expenses and other current assets
Deferred income taxes
Property and equipment, net
Goodwill
Intangible assets, net
Other assets
'''

for col in columns.strip().split("\n"):
    asset_bar = go.Bar(
        x=nvda_BS.index,
        y=nvda_BS[col],
        name=col
    )
    asset_data.append(asset_bar)

layout_assets = go.Layout(
    barmode='stack'
)

fig_bs_assets = go.Figure(data=asset_data, layout=layout_assets)
py.iplot(fig_bs_assets, filename='Total Assets Breakdown')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~taewoo/19.embed" height="525px" width="100%"></iframe>
